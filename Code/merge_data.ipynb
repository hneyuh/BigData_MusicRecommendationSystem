# %%
import pandas as pd
import os

# %%
path = 'D:\BIGDATA_FinalProject/'

# %%
frames = []
for file in os.listdir(path):
    filepath = path + file
    df1 = pd.read_csv(filepath)
    frames.append(df1) 
    result = pd.concat(frames)
df = result

# %%
df.drop(columns=['Unnamed: 0'], inplace= True)

# %%
df.head()
# Out:
#                        id             title   all_artists          album_name  \
# 0  7zgqtptZvhf8GEmdsM2vp2  ...Ready For It?  Taylor Swift    ...Ready For It?
# 1  4Vxu50qVrQcycjRyJQaZLC      Life Changes  Thomas Rhett        Life Changes
# 2  6b8Be6ljOzmkOmFslEb23P         24K Magic    Bruno Mars           24K Magic
# 3  0afhq8XCExXpqazXczTSve       Galway Girl    Ed Sheeran          ÷ (Deluxe)
# 4  1HNkqx9Ahdgi1Ixy2xkKkL        Photograph    Ed Sheeran  x (Deluxe Edition)
#
#    popularity release_date  explicit  speechiness  danceability  energy  ...  \
# 0           0   2017-09-03     False       0.1350         0.615   0.779  ...
# 1          60   2017-09-08     False       0.0576         0.687   0.845  ...
# 2          77   2016-11-17     False       0.0797         0.818   0.803  ...
# 3          77   2017-03-03     False       0.1000         0.624   0.876  ...
# 4          83   2014-06-21     False       0.0476         0.614   0.379  ...
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.0665          0.000000    0.1550    0.453  160.000       208198
# 1        0.1000          0.000000    0.0452    0.809   87.972       190227
# 2        0.0340          0.000000    0.1530    0.632  106.970       225983
# 3        0.0735          0.000000    0.3270    0.781   99.943       170827
# 4        0.6070          0.000464    0.0986    0.201  107.989       258987
#
#    time_signature                                             genres  \
# 0               4                                            ['pop']
# 1               4  ['contemporary country', 'country', 'country r...
# 2               4                               ['dance pop', 'pop']
# 3               4                                  ['pop', 'uk pop']
# 4               4                                  ['pop', 'uk pop']
#
#    artist_pop  Unnamed: 0.1
# 0         100           NaN
# 1          75           NaN
# 2          90           NaN
# 3          92           NaN
# 4          92           NaN
#
# [5 rows x 23 columns]

# %%
df.drop(columns=['Unnamed: 0.1'], inplace= True)

# %%
df
# Out:
#                           id  \
# 0     7zgqtptZvhf8GEmdsM2vp2
# 1     4Vxu50qVrQcycjRyJQaZLC
# 2     6b8Be6ljOzmkOmFslEb23P
# 3     0afhq8XCExXpqazXczTSve
# 4     1HNkqx9Ahdgi1Ixy2xkKkL
# ...                      ...
# 2896  4UFlPCB4THnQ9TlPHqIQow
# 2897  5pSSEkT0963muzzIjsVkrs
# 2898  7gC6Rbllqf1yXNC02e5jz2
# 2899  6Ff77WXC58MkhLE5A1qgY1
# 2900  1is5wwajEk2JW7Nsd63r3m
#
#                                                   title   all_artists  \
# 0                                      ...Ready For It?  Taylor Swift
# 1                                          Life Changes  Thomas Rhett
# 2                                             24K Magic    Bruno Mars
# 3                                           Galway Girl    Ed Sheeran
# 4                                            Photograph    Ed Sheeran
# ...                                                 ...           ...
# 2896          Funeral For A Friend / Love Lies Bleeding    Elton John
# 2897                                    Fool's Overture    Supertramp
# 2898               Heart of the Sunrise - 2003 Remaster           Yes
# 2899  Venus And Mars / Rock Show / Jet - Live / Rema...         Wings
# 2900                                     Mr. Brightside   The Killers
#
#                                              album_name  popularity  \
# 0                                      ...Ready For It?           0
# 1                                          Life Changes          60
# 2                                             24K Magic          77
# 3                                            ÷ (Deluxe)          77
# 4                                    x (Deluxe Edition)          83
# ...                                                 ...         ...
# 2896  Goodbye Yellow Brick Road (40th Anniversary Ce...           0
# 2897                       Even In The Quietest Moments          50
# 2898                           Fragile (Deluxe Edition)          44
# 2899                    Wings Over America (Remastered)           0
# 2900                                           Hot Fuss           0
#
#      release_date  explicit  speechiness  danceability  energy  ...  mode  \
# 0      2017-09-03     False       0.1350         0.615   0.779  ...     1
# 1      2017-09-08     False       0.0576         0.687   0.845  ...     1
# 2      2016-11-17     False       0.0797         0.818   0.803  ...     1
# 3      2017-03-03     False       0.1000         0.624   0.876  ...     1
# 4      2014-06-21     False       0.0476         0.614   0.379  ...     1
# ...           ...       ...          ...           ...     ...  ...   ...
# 2896   1973-10-05     False       0.0465         0.410   0.761  ...     0
# 2897   1977-01-01     False       0.0372         0.406   0.306  ...     1
# 2898   1971-11-26     False       0.0394         0.362   0.507  ...     1
# 2899   1976-12-10     False       0.0468         0.331   0.733  ...     1
# 2900   2004-06-15     False       0.0868         0.342   0.932  ...     1
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.06650          0.000000    0.1550    0.453  160.000       208198
# 1          0.10000          0.000000    0.0452    0.809   87.972       190227
# 2          0.03400          0.000000    0.1530    0.632  106.970       225983
# 3          0.07350          0.000000    0.3270    0.781   99.943       170827
# 4          0.60700          0.000464    0.0986    0.201  107.989       258987
# ...            ...               ...       ...      ...      ...          ...
# 2896       0.01980          0.084700    0.2470    0.193  138.712       666572
# 2897       0.31300          0.007900    0.0727    0.073  135.272       652560
# 2898       0.01740          0.216000    0.1130    0.456  146.641       634440
# 2899       0.08870          0.001740    0.9470    0.380  128.512       620747
# 2900       0.00106          0.000000    0.0938    0.226  148.148       222107
#
#       time_signature                                             genres  \
# 0                  4                                            ['pop']
# 1                  4  ['contemporary country', 'country', 'country r...
# 2                  4                               ['dance pop', 'pop']
# 3                  4                                  ['pop', 'uk pop']
# 4                  4                                  ['pop', 'uk pop']
# ...              ...                                                ...
# 2896               4         ['glam rock', 'mellow gold', 'piano rock']
# 2897               4  ['album rock', 'art rock', 'classic rock', 'gl...
# 2898               3  ['album rock', 'art rock', 'classic rock', 'ja...
# 2899               4  ['album rock', 'art rock', 'beatlesque', 'clas...
# 2900               4  ['alternative rock', 'dance rock', 'modern roc...
#
#       artist_pop
# 0            100
# 1             75
# 2             90
# 3             92
# 4             92
# ...          ...
# 2896          85
# 2897          71
# 2898          62
# 2899          72
# 2900          79
#
# [9901 rows x 22 columns]

# %%
df['title']=df['title'].apply(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9901 entries, 0 to 2900
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                9901 non-null   object
#  1   title             9901 non-null   object
#  2   all_artists       9900 non-null   object
#  3   album_name        9900 non-null   object
#  4   popularity        9901 non-null   int64
#  5   release_date      9901 non-null   object
#  6   explicit          9901 non-null   bool
#  7   speechiness       9901 non-null   float64
#  8   danceability      9901 non-null   float64
#  9   energy            9901 non-null   float64
#  10  key               9901 non-null   int64
#  11  loudness          9901 non-null   float64
#  12  mode              9901 non-null   int64
#  13  acousticness      9901 non-null   float64
#  14  instrumentalness  9901 non-null   float64
#  15  liveness          9901 non-null   float64
#  16  valence           9901 non-null   float64
#  17  tempo             9901 non-null   float64
#  18  duration_ms       9901 non-null   int64
#  19  time_signature    9901 non-null   int64
#  20  genres            9901 non-null   object
#  21  artist_pop        9901 non-null   int64
# dtypes: bool(1), float64(9), int64(6), object(6)
# memory usage: 1.7+ MB

# %%
gen1 = []
for i in df.genres:
    string1 = i.replace("'", "").replace(" ","_").replace(",_", ", ")
    gen1.append(string1)

# %%
df['genres_list'] = gen1

# %%
gen = []
for i in df.genres:
    string = i.replace('[', '').replace(']', '').replace("'", "").replace(" ","_").replace(",_", ", ").replace(", ", " ")
    gen.append(string)

# %%
df['genres'] = gen

# %%
df.head(5)
# Out:
#                        id             title   all_artists          album_name  \
# 0  7zgqtptZvhf8GEmdsM2vp2  ...Ready For It?  Taylor Swift    ...Ready For It?
# 1  4Vxu50qVrQcycjRyJQaZLC      Life Changes  Thomas Rhett        Life Changes
# 2  6b8Be6ljOzmkOmFslEb23P         24K Magic    Bruno Mars           24K Magic
# 3  0afhq8XCExXpqazXczTSve       Galway Girl    Ed Sheeran          ÷ (Deluxe)
# 4  1HNkqx9Ahdgi1Ixy2xkKkL        Photograph    Ed Sheeran  x (Deluxe Edition)
#
#    popularity release_date  explicit  speechiness  danceability  energy  ...  \
# 0           0   2017-09-03     False       0.1350         0.615   0.779  ...
# 1          60   2017-09-08     False       0.0576         0.687   0.845  ...
# 2          77   2016-11-17     False       0.0797         0.818   0.803  ...
# 3          77   2017-03-03     False       0.1000         0.624   0.876  ...
# 4          83   2014-06-21     False       0.0476         0.614   0.379  ...
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.0665          0.000000    0.1550    0.453  160.000       208198
# 1        0.1000          0.000000    0.0452    0.809   87.972       190227
# 2        0.0340          0.000000    0.1530    0.632  106.970       225983
# 3        0.0735          0.000000    0.3270    0.781   99.943       170827
# 4        0.6070          0.000464    0.0986    0.201  107.989       258987
#
#    time_signature                                     genres  artist_pop  \
# 0               4                                        pop         100
# 1               4  contemporary_country country country_road          75
# 2               4                              dance_pop pop          90
# 3               4                                 pop uk_pop          92
# 4               4                                 pop uk_pop          92
#
#                                      genres_list
# 0                                          [pop]
# 1  [contemporary_country, country, country_road]
# 2                               [dance_pop, pop]
# 3                                  [pop, uk_pop]
# 4                                  [pop, uk_pop]
#
# [5 rows x 23 columns]

# %%
df.to_csv('SpotifyDataCrawling.csv')
